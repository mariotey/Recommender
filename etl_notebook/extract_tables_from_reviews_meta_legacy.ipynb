# %%
import os
import numpy as np
import pandas as pd
import json
from datetime import datetime
from tqdm import tqdm
tqdm.pandas()

# %%
review_df = pd.read_parquet("../data/output/review_data.parquet")
review_df = review_df.reset_index(names="review_id")
review_df
# Out:
#          review_id        asin parent_asin                       user_id  \
# 0                0  b07bfs3g7p  b0bqsk9qcf  agci7fah4gl5fi65hylkwtmfz2cq
# 1                1  b00ctq6sig  b00ctq6sig  ahspldnw5oouk2plh7gxlacfbznq
# 2                2  b0066wjlu6  b0066wjlu6  ahspldnw5oouk2plh7gxlacfbznq
# 3                3  b00kcymawk  b00kcymawk  ah6catodivpvuojewhrsrcskaoha
# 4                4  b00p1rk566  b00p1rk566  aeiny4xoinmmjck5gz3m6mmhbn6a
# ...            ...         ...         ...                           ...
# 4880176    4880176  b0763n3mvw  b0763n3mvw  agokecumai3w6mc7a7kbfbjvpn7q
# 4880177    4880177  b00et56y48  b00et56y48  ah6amundosz2sgdidmysre4rnmdq
# 4880178    4880178  b009zkspdk  b009zkspdk  ah4pj73qn75ajm5vsct53aoadcga
# 4880179    4880179  b00m9j3ioa  b00m9j3ioa  ahqetdykhvdngmgbwvjl6vjxjgfq
# 4880180    4880180  b01i5omskm  b01i5omskm  ah22767frobcshb4y3m4o37qetiq
#
#         review_datetime                              review_title  \
# ...

# %%
meta_df = pd.read_parquet("../data/output/meta_data.parquet")
meta_df = meta_df.drop(columns=["item_rating"])
meta_df
# Out:
#       parent_asin                                         item_title  \
# 0      b00vrpsgeo                                 accupressure guide
# 1      b00nwqxxhq  ankylosaurus fights back - smithsonian's prehi...
# 2      b00rfkp6ac                                       mahjong 2015
# 3      b00sp2qu0e                              jewels brick breakout
# 4      b01dzit64o                       traffic police: off-road cub
# ...           ...                                                ...
# 89246  b006kwvrgi  how to start a commercial loan broker plus bus...
# 89247  b000j54pra                            norton uninstall deluxe
# 89248  b00mg0ohb0          beginning pro tools le 8 [instant access]
# 89249  b001gn6yuk  tell me more spanish performance version 9 (2 ...
# 89250  b0751q59hc  veryfi - receipts & bills tracker, expense rep...
#
#               main_category  \
# 0      appstore for android
# 1      appstore for android
# 2      appstore for android
# ...

# %%
def count_review_images(image_list):
    """Safely count number of images"""
    if isinstance(image_list, list):
        return len(image_list)
    elif pd.isna(image_list):
        return np.nan
    else:
        # If it's not a list (maybe a string or other type), try to convert
        try:
            if isinstance(image_list, str):
                import ast
                parsed = ast.literal_eval(image_list)
                return len(parsed) if isinstance(parsed, list) else 1
            else:
                return 1
        except:
            return 0

def count_item_img(img_dict):
    hi_res = img_dict.get("hi_res", [])
    large = img_dict.get("large", [])
    thumb = img_dict.get("thumb", [])

    return (
        sum(1 for x in hi_res if x) +
        sum(1 for x in large if x) +
        sum(1 for x in thumb if x)
    )

def count_item_videos(video_dict):
    url_list = video_dict.get("url", [])
    return len(url_list)

def count_item_variant(img_dict):
    variant = img_dict.get("variant", [])
    return len(variant)

def get_release_datetime(detail_str):
    detail_dict = json.loads(detail_str)
    date_str = detail_dict.get("Date First Available", [])

    if date_str == []:
        return np.nan

    return datetime.strptime(date_str, "%B %d, %Y")

def get_country_manufacturer(detail_str):
    detail_dict = json.loads(detail_str)
    manu_str = detail_dict.get("Manufacturer", [])

    if manu_str == []:
        return np.nan

    return str(manu_str).strip().lower()

def get_country_origin(detail_str):
    detail_dict = json.loads(detail_str)
    origin_str = detail_dict.get("Country of Origin", [])

    if origin_str == []:
        return np.nan

    return str(origin_str).strip().lower()

merged_df = (
    review_df
    .merge(
        meta_df,
        how="left",
        on="parent_asin"
    )
    .dropna(subset=["price"])
)

merged_df["num_review_img"] = merged_df["review_images"].apply(count_review_images)
merged_df["num_item_img"] = merged_df["item_images"].apply(count_item_img)
merged_df["num_item_videos"] = merged_df["item_videos"].apply(count_item_videos)
merged_df["num_item_variant"] = merged_df["item_images"].apply(count_item_variant)

# merged_df["item_release_datetime"] = merged_df["details"].apply(get_release_datetime)
# merged_df["item_manufacturer"] = merged_df["details"].apply(get_country_manufacturer)
# merged_df["item_country_origin"] = merged_df["details"].apply(get_country_origin)

merged_df = merged_df.explode("categories").rename(columns={"categories": "category"})
merged_df["category"] = merged_df["category"].fillna("nan")

# Modification to category values
merged_df["category"] = merged_df["category"].replace({
    "accounting": "accounting & finance",
    "antivirus": "antivirus & security",
    "education": "education & reference",
    "free one-day shipping i software": "free one-day shipping for software",
    "free one-day shipping on select software with your citi card": "free one-day shipping for software",
    "medicine": "medicine & health sciences",
    "photography": "photography & graphic design",
    "programming": "programming & web development",
    "spreadsheet": "spreadsheet & database",
    "training": "training & tutorials"
})

merged_df
# Out:
#          review_id        asin parent_asin                       user_id  \
# 0                0  b07bfs3g7p  b0bqsk9qcf  agci7fah4gl5fi65hylkwtmfz2cq
# 0                0  b07bfs3g7p  b0bqsk9qcf  agci7fah4gl5fi65hylkwtmfz2cq
# 0                0  b07bfs3g7p  b0bqsk9qcf  agci7fah4gl5fi65hylkwtmfz2cq
# 1                1  b00ctq6sig  b00ctq6sig  ahspldnw5oouk2plh7gxlacfbznq
# 2                2  b0066wjlu6  b0066wjlu6  ahspldnw5oouk2plh7gxlacfbznq
# ...            ...         ...         ...                           ...
# 4880175    4880175  b07th23gwv  b07th23gwv  afxn4h3e55alrifjpsiqfyoxklha
# 4880176    4880176  b0763n3mvw  b0763n3mvw  agokecumai3w6mc7a7kbfbjvpn7q
# 4880177    4880177  b00et56y48  b00et56y48  ah6amundosz2sgdidmysre4rnmdq
# 4880178    4880178  b009zkspdk  b009zkspdk  ah4pj73qn75ajm5vsct53aoadcga
# 4880180    4880180  b01i5omskm  b01i5omskm  ah22767frobcshb4y3m4o37qetiq
#
#         review_datetime                         review_title  \
# ...

# %%
user_df = (
    merged_df[merged_df["verified_purchase"] == True]
    .groupby(["user_id", "main_category", "category"])
    .agg({
        "review_id": "count",
        "review_rating": "mean",
        "review_datetime": "max",
        # "helpful_vote": "sum",
        # "num_review_img": "sum"
    })
    .reset_index()
    .rename(columns={
        "review_id": "num_review_given",
        "review_rating": "avg_rating_given",
        "review_datetime": "latest_user_datetime"
    })
)

user_df
# Out:
#                               user_id         main_category category  \
# 0        ae22232ob6s7uac75jufyrgbshiq  appstore for android      nan
# 1        ae22236afrrsmqikgg7tptb75qea  appstore for android      nan
# 2        ae2224fsuk5av5r2usyxinuntw7q  appstore for android      nan
# 3        ae2226penzttcdkfgrtucux2nu2q  appstore for android      nan
# 4        ae2227qsjsf6hv3xttigqapa6whq  appstore for android      nan
# ...                               ...                   ...      ...
# 2330390  ahzzzipdm2xjez4rz7bns4yhccka  appstore for android      nan
# 2330391  ahzzzngyuwv64yjbzgd3uc5y3liq  appstore for android      nan
# 2330392  ahzzzuba3pttfi67ios2mftjavea  appstore for android      nan
# 2330393  ahzzzy4dflawpbqyfqfwvacngura  appstore for android      nan
# 2330394  ahzzzyhanwl2ow5pgxdobutjxcta  appstore for android      nan
#
#          num_review_given  avg_rating_given latest_user_datetime
# 0                       1          5.000000           2020-05-16
# ...

# %%
item_df = (
    merged_df
    .groupby([
        "parent_asin",
        "main_category", "category",
        "num_item_variant",
        "num_item_img", "num_item_videos"
    ])
    .agg({
        "user_id": "count",
        "review_datetime": "max",
        "review_rating": "mean",
        "price": "mean"
    })
    .rename(columns={
        "user_id": "num_review_received",
        "review_datetime": "latest_review_datetime",
        "review_rating": "avg_rating_received",
        "price": "avg_price"
    })
    .reset_index()
)

item_df
# Out:
#       parent_asin main_category                  category  num_item_variant  \
# 0      0028217012      software                       nan                 1
# 1      0077563387      software                   courses                 1
# 2      0077563387      software                  software                 1
# 3      0321413849      software                       nan                 1
# 4      0439026008      software                    brands                10
# ...           ...           ...                       ...               ...
# 75747  b0cbn6ygz3      software             office suites                 6
# 75748  b0cbn6ygz3      software                  software                 6
# 75749  b0cc7jglms      software      antivirus & security                10
# 75750  b0cc7jglms      software  internet security suites                10
# 75751  b0cc7jglms      software                  software                10
#
# ...

# %%
# import re
#
# def normalize_and_join(desc_array):
#     """
#     Takes an array of strings, ensures each ends with a period,
#     then joins them into a single string separated by space.
#     """
#     normalized = []
#     for s in desc_array:
#         s = s.strip()  # remove leading/trailing whitespace
#         if not s:      # skip empty strings
#             continue
#         if not s.endswith("."):
#             s += "."
#         normalized.append(s)
#     return " ".join(normalized)

# def clean_text(text):
#     text = text.strip()
#     text = " ".join(text.split())  # normalize spaces
#     # remove unwanted special characters (keep basic punctuation)
#     text = re.sub(r"[^a-zA-Z0-9.,\- ]+", "", text)
#     return text

# item_desc = merged_df[["parent_asin", "description"]].reset_index(drop=True)
# item_desc["modified_desc"] = item_desc["description"].progress_apply(normalize_and_join)
# item_desc["modified_desc"] = item_desc["modified_desc"].progress_apply(clean_text)

# # Chunk long description
# def chunk_by_words(text, max_words=100):
#     words = text.split()
#     return [" ".join(words[i:i+max_words]) for i in range(0, len(words), max_words)]

# # Flatten each description into multiple chunks, keep parent_asin mapping
# rows = []
# for row in tqdm(item_desc.itertuples(index=False), desc="Chunking..."):
#     text = row.modified_desc

#     chunks = chunk_by_words(text, max_words=100)

#     for idx, chunk in enumerate(chunks):
#         rows.append({
#             "parent_asin": row.parent_asin,
#             "chunk_idx": idx,
#             "desc_chunk": chunk
#         })

# chunked_df = pd.DataFrame(rows)

# chunked_df

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer

# vectorizer = TfidfVectorizer(
#     max_features=5000,   # limit vocab size
#     stop_words="english", # remove common English words
#     ngram_range=(1,2)    # optional: unigrams + bigrams
# )

# # Fit TF-IDF on all chunks and transform them into vectors
# tfidf_matrix = vectorizer.fit_transform(chunked_df["desc_chunk"])

# # Get feature names
# feature_names = vectorizer.get_feature_names_out()

# # Convert sparse matrix to dense DataFrame
# tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# # Make sure indexes align
# tfidf_df.index = chunked_df.index

# # Combine with chunked_df
# chunked_with_embeddings = pd.concat([
#     chunked_df.reset_index(drop=True),
#     tfidf_df.reset_index(drop=True)],
#     axis=1
# )

# chunked_with_embeddings

# %% [markdown]
# ### Export DataFrame

# %%
output_dir = "../data/input"

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Export DataFrame
merged_df.to_parquet(f"{output_dir}/merged_df.parquet", index=False)
user_df.to_parquet(f"{output_dir}/user_df.parquet", index=False)
item_df.to_parquet(f"{output_dir}/item_df.parquet", index=False)
# chunked_with_embeddings.to_parquet(f"{output_dir}/item_desc_embeddings.parquet", index=False)
